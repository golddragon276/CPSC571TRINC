# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np

os.chdir("C:\dataset")
df = pd.read_csv("TrafficIn2.csv")

df = df.loc[:,['INCIDENT INFO','Longitude','Latitude','DewPoint','RelativeHumidity','WindDirection','WindSpeed','Visibility','Pressure','Weather']]
df = df.dropna()

display(df)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import os 

# Setting up Lateral and Longitude Division
HOR = 50.99
VER = -114.0



SE = df[df.Latitude < HOR]
SE = SE[SE.Longitude > VER]

#Set Latitude and Longitude
Y_axis = SE[['Latitude']]
X_axis = SE[['Longitude']]

K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]


#Estimate 
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]# Visualize
plt.plot(K_clusters, score)

X=SE.loc[:,['INCIDENT INFO','Latitude','Longitude']]

#Estimate the Elbow Curve (for the number of clusters required)


plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

#Set the number of clusters into the kmeans as provided by the estimate above

kmeans = KMeans(n_clusters = 3, init ='k-means++')
kmeans.fit(X[X.columns[1:3]]) # Compute k-means clustering

X['cluster_label'] = kmeans.fit_predict(X[X.columns[1:3]])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(X[X.columns[1:3]]) # Labels of each point

X.plot.scatter(x = 'Latitude', y = 'Longitude', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.5)

X = X[['INCIDENT INFO','cluster_label']]

# merging data back to the data set

data = df.merge(X, left_on='INCIDENT INFO', right_on='INCIDENT INFO')

data.to_csv ('SEdata.csv', index=None, header = True)

centers = kmeans.cluster_centers_
print(centers)
# Out:
#                                            INCIDENT INFO   Longitude  \
# 0      Falconridge Drive b/w Falconridge Boulevard an... -113.952457
# 1      Falconridge Drive b/w Falsbridge Drive and Fal... -113.952505
# 2                Falconridge Cr and Falconridge Drive NE -113.952495
# 3                  James Mckevitt Road and 162 Avenue SW -114.098963
# 4                    162 Avenue and Somercrest Street SW -114.089486
# ...                                                  ...         ...
# 16957  Northbound Deerfoot Trail at McKnight Boulevar... -114.047814
# 16958                          58 Avenue and 2 Street SW -114.068609
# 16965  Southbound Symons Valley Road at Kincora Glen ... -114.129824
# 16967             Stoney Trail at Chaparral Boulevard SE -114.025651
# 16968     John Laurie Boulevard at Hawkwood Boulevard NW -114.170252
#
#         Latitude DewPoint RelativeHumidity WindDirection WindSpeed Visibility  \
# ...
