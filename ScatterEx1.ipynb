# %%
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot

import pandas as pd 

mapbox_access_token = 'pk.eyJ1IjoiZ29sZGRyYWdvbjI3NiIsImEiOiJja3dsNnAycTAwNDJzMm9tcm55bmc3NXRnIn0.NSfA5B_if5vXzcvslI7aIA'
import os

os.chdir("C:\dataset")
df = pd.read_csv("TrafficIn.csv")

t_lat = df.Latitude
t_long = df.Longitude
locations_name = df["INCIDENT INFO"]
des = df.DESCRIPTION

dfj = df[df["START_DT"].str.contains("2020-01")]
dfj_lat = dfj.Latitude
dfj_long = dfj.Longitude
dfj_n = dfj["INCIDENT INFO"]



os.chdir("C:\dataset")
df = pd.read_csv("TrafficIn.csv")

fig = go.Figure()

fig.add_trace(go.Scattermapbox(
        lat=t_lat,
        lon=t_long,
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=18,
            color='rgb(255, 0, 0)',
            opacity=0.1
        ),
        text=locations_name,
        hoverinfo='text'
    ))

fig.update_layout(
    title='Calgary Traffic incidents',
    autosize=True,
    hovermode='closest',
    showlegend=False,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=51,
            lon=-114
        ),
        pitch=0,
        zoom=9,
        style='light'
    ),
)

fig.show()
# Out:
# <div>                            <div id="7ced74ef-a823-4e38-8e25-53c779e0a9e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ced74ef-a823-4e38-8e25-53c779e0a9e3")) {                    Plotly.newPlot(                        "7ced74ef-a823-4e38-8e25-53c779e0a9e3",                        [{"hoverinfo":"text","lat":[51.05887765,50.99805615,51.06719295,51.09603511,51.01469371,51.08157011,51.0933886,51.08671996,50.8965613,50.93945486,51.10997607,51.04764484,51.04278897,51.13128255,51.06286867,51.0148979,51.17698975,50.88744878,50.9050948,50.95053319,50.91458927,50.90643895,51.02490634,50.9322177,51.04516322,50.99306306,50.9930088,51.040139,51.10114235,51.06002275,51.09616614,51.09597443,51.0961604,51.14169681,51.04812985,51.16544652,51.03870242,51.05
# ...
