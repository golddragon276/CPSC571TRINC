# %%
import os
import pandas as pd 

Following https://www.geeksforgeeks.org/ml-optics-clustering-implementing-using-sklearn/
import numpy as np, matplotlib.pyplot as plt
from sklearn.cluster import OPTICS, cluster_optics_dbscan
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize, StandardScaler
np.seterr(divide='ignore', invalid='ignore')


os.chdir("C:\dataset")
df = pd.read_csv("TrafficIn.csv")


#Cleaning here

#remove unnamed

df = df.drop(df.columns[[0,3,4,5,9,8,10,11,15,20]], axis = 1 )


#remove null/NaN
df = df.dropna()
display(df)

#Split by Month 
#Geospatial DBScans clustering 



lonlat = df[['Temperature','Longitude','Latitude']].copy()
lonlat.fillna(method ='ffill', inplace = True)
display (lonlat)

# Scaling the data to bring all the attributes to a comparable level
scaler = StandardScaler()
lonlat_scaled = scaler.fit_transform(lonlat)

# Normalizing the data so that the data
# approximately follows a Gaussian distribution
lonlat_normalized = normalize(lonlat_scaled)

# Converting the numpy array into a pandas DataFrame
lonlat_normalized = pd.DataFrame(lonlat_normalized)

# Renaming the columns
lonlat_normalized.columns = lonlat.columns

lonlat_normalized.head()


# Building the OPTICS Clustering model
optics_model = OPTICS(min_samples = 10, xi = 0.05, min_cluster_size = 0.05)

# Training the model
optics_model.fit(lonlat_normalized)

# Producing the labels according to the DBSCAN technique with eps = 0.5
labels1 = cluster_optics_dbscan(reachability = optics_model.reachability_,
								core_distances = optics_model.core_distances_,
								ordering = optics_model.ordering_, eps = 0.5)

# Producing the labels according to the DBSCAN technique with eps = 2.0
labels2 = cluster_optics_dbscan(reachability = optics_model.reachability_,
								core_distances = optics_model.core_distances_,
								ordering = optics_model.ordering_, eps = 2)

# Creating a numpy array with numbers at equal spaces till
# the specified range
space = np.arange(len(lonlat_normalized))

# Storing the reachability distance of each point
reachability = optics_model.reachability_[optics_model.ordering_]

# Storing the cluster labels of each point
labels = optics_model.labels_[optics_model.ordering_]

print(labels)

# Defining the framework of the visualization
plt.figure(figsize =(10, 7))
G = gridspec.GridSpec(2, 3)
ax1 = plt.subplot(G[0, :])
ax2 = plt.subplot(G[1, 0])
ax3 = plt.subplot(G[1, 1])
ax4 = plt.subplot(G[1, 2])

# Plotting the Reachability-Distance Plot
colors = ['c.', 'b.', 'r.', 'y.', 'g.']
for Class, colour in zip(range(0, 5), colors):
	Xk = space[labels == Class]
	Rk = reachability[labels == Class]
	ax1.plot(Xk, Rk, colour, alpha = 0.3)
ax1.plot(space[labels == -1], reachability[labels == -1], 'k.', alpha = 0.3)
ax1.plot(space, np.full_like(space, 2., dtype = float), 'k-', alpha = 0.5)
ax1.plot(space, np.full_like(space, 0.5, dtype = float), 'k-.', alpha = 0.5)
ax1.set_ylabel('Reachability Distance')
ax1.set_title('Reachability Plot')

# Plotting the OPTICS Clustering
colors = ['c.', 'b.', 'r.', 'y.', 'g.']
for Class, colour in zip(range(0, 5), colors):
	Xk = lonlat_normalized[optics_model.labels_ == Class]
	ax2.plot(Xk.iloc[:, 0], Xk.iloc[:, 1], colour, alpha = 0.3)
	
ax2.plot(lonlat_normalized.iloc[optics_model.labels_ == -1, 0],
		lonlat_normalized.iloc[optics_model.labels_ == -1, 1],
	'k+', alpha = 0.1)
ax2.set_title('OPTICS Clustering')

# Plotting the DBSCAN Clustering with eps = 0.5
colors = ['c', 'b', 'r', 'y', 'g', 'greenyellow']
for Class, colour in zip(range(0, 6), colors):
	Xk = lonlat_normalized[labels1 == Class]
	ax3.plot(Xk.iloc[:, 0], Xk.iloc[:, 1], colour, alpha = 0.3, marker ='.')
		
ax3.plot(lonlat_normalized.iloc[labels1 == -1, 0],
		lonlat_normalized.iloc[labels1 == -1, 1],
	'k+', alpha = 0.1)
ax3.set_title('DBSCAN clustering with eps = 0.5')

# Plotting the DBSCAN Clustering with eps = 2.0
colors = ['c.', 'y.', 'm.', 'g.']
for Class, colour in zip(range(0, 4), colors):
	Xk = lonlat_normalized.iloc[labels2 == Class]
	ax4.plot(Xk.iloc[:, 0], Xk.iloc[:, 1], colour, alpha = 0.3)
		
ax4.plot(lonlat_normalized.iloc[labels2 == -1, 0],
		lonlat_normalized.iloc[labels2 == -1, 1],
	'k+', alpha = 0.1)
ax4.set_title('DBSCAN Clustering with eps = 2.0')


plt.tight_layout()
plt.show()
# Out:
#                                           INCIDENT INFO  \
# 1                                     3619 61 Avenue SE
# 2             Northbound Deerfoot Trail at 16 Avenue NE
# 6                 Shaganappi Trail and Varsity Drive NW
# 7               Westbound 37 Avenue and Barlow Trail NE
# 8                      52 Street and Mahogany Street SE
# ...                                                 ...
# 5776              James Mckevitt Road and 162 Avenue SW
# 5777  162 Avenue b/w James McKevitt Road and 6 Stree...
# 5778            Falconridge Cr and Falconridge Drive NE
# 5779  Falconridge Drive b/w Falsbridge Drive and Fal...
# 5780  Falconridge Drive b/w Falconridge Boulevard an...
#
#                                             DESCRIPTION   Longitude  \
# 1          There is an incident involving a pedestrian. -113.981403
# 2      Single vehicle incident. Blocking the right lane -114.026760
# 6                               Multi-vehicle incident. -114.154945
# ...
